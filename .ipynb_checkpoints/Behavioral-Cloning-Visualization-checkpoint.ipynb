# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import numpy as np

# %%
## Load driving data from csv file "../data/driving_log.csv" into pandas dataframe
csv_df = pd.read_csv("data/driving_log.csv", index_col=False)

# set the data frame columns
csv_df.columns = ['center', 'left', 'right', 'steer', 'throttle', 'brake', 'speed']

## Shuffle
csv_df = csv_df.sample(n=len(csv_df))

## Training and Validation Data
training_count = int(0.8 * len(csv_df))
training_data, validation_data = csv_df[:training_count].reset_index(), csv_df[training_count:].reset_index()

# %%
DATA_PATH = "/Users/umarqattan/Desktop/CarND-Behavioral-Cloning-P3/data/"

# %% [markdown]
# ## Steering Angle Distribution

# %%
## Plotting Steering Angle
training_data.steer.plot.hist(bins=10)
plt.xlabel('Steering Angle')

# %% [markdown]
# ## Cropping Image

# %%
plt.subplot(1,2,1)
img = plt.imread("/Users/umarqattan/Desktop/CarND-Behavioral-Cloning-P3/data/"+training_data['center'].iloc[5].strip())
plt.imshow(img)
plt.title('Original Image')
plt.yticks([])
plt.xticks([])

plt.subplot(1,2,2)
img = plt.imread("/Users/umarqattan/Desktop/CarND-Behavioral-Cloning-P3/data/"+training_data['center'].iloc[5].strip())
plt.imshow(img[60:135, : ])
plt.title('Cropped Image')
plt.yticks([])
plt.xticks([])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %% [markdown]
# ## Flipping Images

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(1,2,1)
img = plt.imread("/Users/umarqattan/Desktop/CarND-Behavioral-Cloning-P3/data/"+training_data['center'].iloc[10].strip())
plt.imshow(img)
plt.title('Center Image')
plt.yticks([])
plt.xticks([])
plt.xlabel('Steering Angle: ' + str(training_data['steer'].iloc[10]))

plt.subplot(1,2,2)
img = plt.imread("/Users/umarqattan/Desktop/CarND-Behavioral-Cloning-P3/data/"+training_data['center'].iloc[10].strip())
plt.imshow(np.fliplr(img))
plt.title('Flipped Image')
plt.yticks([])
plt.xticks([])
plt.xlabel('Biased Steering Angle: ' + str(-training_data['steer'].iloc[169]))

# %% [markdown]
# ## Angle Correction for Right and Left Images

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(1,3,1)
img = plt.imread("/Users/umarqattan/Desktop/CarND-Behavioral-Cloning-P3/data/"+training_data['left'].iloc[10].strip())
plt.imshow(img)
plt.title('Left Image')
plt.yticks([])
plt.xticks([])
plt.xlabel('Corrected Steering Angle: ' + str(training_data['steer'].iloc[169] + 0.25))

plt.subplot(1,3,2)
img = plt.imread("/Users/umarqattan/Desktop/CarND-Behavioral-Cloning-P3/data/"+training_data['center'].iloc[10].strip())
plt.imshow(img)
plt.title('Center Image')
plt.yticks([])
plt.xticks([])
plt.xlabel('Steering Angle: ' + str(training_data['steer'].iloc[169]))


plt.subplot(1,3,3)
img = plt.imread("/Users/umarqattan/Desktop/CarND-Behavioral-Cloning-P3/data/"+training_data['right'].iloc[10].strip())
plt.imshow(img)
plt.title('Right Image')
plt.yticks([])
plt.xticks([])
plt.xlabel('Corrected Steering Angle: ' + str(training_data['steer'].iloc[169] - 0.25))

# %% [markdown]
# ## Translating Images

# %%
import cv2

def trans_image(image, steer):
    """ Returns translated image and 
    corrsponding steering angle.
    """
    trans_range = 100
    tr_x = trans_range * np.random.uniform() - trans_range / 2
    steer_ang = steer + tr_x / trans_range * 2 * .2
    tr_y = 0
    M = np.float32([[1, 0, tr_x], [0, 1, tr_y]])
    image_tr = cv2.warpAffine(image, M, (320,160))
    return image_tr, steer_ang

steer_ang = training_data['steer'].iloc[169]
new_img, new_steer_ang = trans_image(img, steer_ang)

plt.subplot(1,2,1)
img = plt.imread("/Users/umarqattan/Desktop/CarND-Behavioral-Cloning-P3/data/"+training_data['center'].iloc[169].strip())
plt.imshow(img)
plt.title('Original Image')
plt.yticks([])
plt.xticks([])
plt.xlabel('Steering Angle: ' + str(steer_ang))

plt.subplot(1,2,2)
plt.imshow(new_img)
plt.title('Translated Image')
plt.yticks([])
plt.xticks([])
plt.xlabel('Biased Steering Angle: ' + str(new_steer_ang))
